# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
import torch
import torch.nn as nn
import torch.nn.functional as F

from torch.distributions.multivariate_normal import MultivariateNormal

import nf_utils as nf

# %%
device = 'cuda'
# device = 'cpu'  # uncomment this line to run the model on the CPU

# %% [markdown]
# # Project 1, part 1: Normalizing Flows (100 pt)
# In this notebook we will implement two normalizing flow (NF) layers, stack tranformations, and train the model with maximum likelihood on 3 datasets.
#
# ## Your task
# Complete the missing code. Make sure that all the functions follow the provided specification, i.e. the output of the function exactly matches the description in the docstring.
#
# Do not add or modify any code outside of the following comment blocks
# ```
# ##########################################################
# # YOUR CODE HERE
# .....
# ##########################################################
# ```
# After you fill in all the missing code, restart the kernel and re-run all the cells in the notebook.
#
# The following things are **NOT** allowed:
# - Using additional `import` statements
# - Using `torch.autograd.functional.jacobian`
# - Using `torch.det`
# - Using `torch.distributions`
# - Copying / reusing code from other sources (e.g. code by other students)
#
# If you plagiarize even for a single project task, you won't be eligible for the bonus this semester.

# %% [markdown]
# # 1. Normalizing Flow

# %% [markdown]
# All transformations (i.e. normalizing flow layers) inherit from the class `nf.Flow` that is included in `nf_utils.py`. The class `nf.Flow` has the following methods:
# - `forward`: Apply the transformation and compute the Jacobian determinant (Slide 31)
# - `inverse`: Apply the inverse transformation (if it exists in closed form) and compute the Jacobian determinant of the *inverse* transformation (Slide 27)
#
# Additonally, by calling `Flow.get_inverse()` we "reverse the direction" of the transformation. That is, the foward transformation becomes the inverse, and vice versa..
#
# In this section, we will implement two NF transformations:
# - Affine transformation
# - Radial transformation

# %% [markdown]
# ### Affine tranformation

# %% [markdown]
# An affine tranformation scales each dimension independently and shifts the inputs by a constant offset. The tranformation is defined as follows:
#
# $$f(\mathbf{z})= \exp(\mathbf{a}) \odot \mathbf{z} + \mathbf{b}$$
#
# where parameters $\mathbf{a} \in \mathbb{R}^{D}$ and $\mathbf{b} \in \mathbb{R}^{D}$.
# We apply $\exp$ elementwise to $\mathbf{a}$ to obtain positive scales for each dimension.
#
# Note that we can compute the inverse of this transformation analytically.

# %% [markdown]
# #### Task 1: Affine - forward (10 pt)
# Implement the `forward` method in the class `Affine`.
#
#
# #### Task 2: Affine - inverse (10 pt)
# Implement the `inverse` method in the class `Affine`.

# %%
class Affine(nf.Flow):
    """Affine transformation y = e^a * x + b."""

    def __init__(self, dim=2):
        """Create and init an affine transformation.

        Args:
            dim: dimension of input/output data. int
        """
        super().__init__()
        self.dim = dim
        self.log_scale = nn.Parameter(torch.zeros(self.dim))  # a
        self.shift = nn.Parameter(torch.zeros(self.dim))  # b

    def forward(self, x):
        """Compute the forward transformation given an input x.

        Args:
            x: input sample. shape [batch_size, dim]

        Returns:
            y: sample after forward tranformation. shape [batch_size, dim]
            log_det_jac: log determinant of the jacobian of the forward tranformation, shape [batch_size]
        """
        ##########################################################
        # YOUR CODE HERE
        y = x * self.log_scale.exp() + self.shift
        log_det_jac = self.log_scale.sum().expand(x.shape[0])
        ##########################################################
        return y, log_det_jac

    def inverse(self, y):
        """Compute the inverse transformation given an input y.

        Args:
            y: input sample. shape [batch_size, dim]

        Returns:
            x: sample after inverse tranformation. shape [batch_size, dim]
            inv_log_det_jac: log determinant of the jacobian of the inverse tranformation, shape [batch_size]
        """
        ##########################################################
        # YOUR CODE HERE
        x = (y - self.shift) * self.log_scale.neg().exp()
        inv_log_det_jac = -self.log_scale.sum().expand(y.shape[0])
        ##########################################################
        return x, inv_log_det_jac

# %% [markdown]
# ### Radial tranformation

# %% [markdown]
# A radial flow is a simple but expressive transformation. It has been introduced in this [paper](https://arxiv.org/pdf/1505.05770.pdf) by Rezende and Mohamed. The transformation is defined as:
#
# $$f(\mathbf{z}) =  \mathbf{z} + \beta h(\alpha, r)(\mathbf{z} - \mathbf{z_0})$$
#
# where $r= \|\mathbf{z} - \mathbf{z_0}\|_2$, $h(\alpha, r) = \frac{1}{\alpha + r}$ and parameters $\mathbf{z_0} \in \mathbb{R}^{D}$, $\alpha \in \mathbb{R}_+$ and $\beta \in \mathbb{R}$. The parameters need to satisfy the constraints $\alpha > 0$ and $\beta \geq -\alpha$ for the transformation to be invertible.
#
# To enfore the above constraints in practice, we can do the following.
#
# - Define a learnable parameter $\tilde{\alpha} \in \mathbb{R}$ and obtain $\alpha$ for the transformation as $\alpha = \textrm{softplus}(\tilde{\alpha})$.
# - Define a learnable parameter $\tilde{\beta} \in \mathbb{R}$ and obtain $\beta$ for the transformation as $\beta =-\alpha + \textrm{softplus}(\tilde{\beta}) > -\alpha$.

# %% [markdown]
# #### Task 3: Radial - forward (25 pt)
# Implement the `forward` method in the class `Radial`.

# %%
class Radial(nf.Flow):
    """Radial transformation."""

    def __init__(self, dim=2):
        """Create and initialize an affine transformation.

        Args:
            dim: dimension of input/output data, int
        """
        super().__init__()
        self.dim = dim
        self.x0 = nn.Parameter(torch.Tensor(self.dim,)) # Vector used to parametrize z_0 
        self.pre_alpha = nn.Parameter(torch.Tensor(1,)) # Scalar used to indirectly parametrized \alpha
        self.pre_beta = nn.Parameter(torch.Tensor(1,)) # Scaler used to indireclty parametrized \beta
        
        stdv = 1. / np.sqrt(self.dim)
        self.pre_alpha.data.uniform_(-stdv, stdv)
        self.pre_beta.data.uniform_(-stdv, stdv)
        self.x0.data.uniform_(-stdv, stdv)

    def forward(self, x):
        """Compute the forward transformation for the given input x.
        
        Args:
            x: input sample, shape [batch_size, dim]

        Returns:
            y: sample after forward tranformation, shape [batch_size, dim]
            log_det_jac: log determinant of the jacobian of the forward tranformation, shape [batch_size]
        """
        ##########################################################
        # YOUR CODE HERE
        alpha = F.softplus(self.pre_alpha)
        beta = -alpha + F.softplus(self.pre_beta)

        diff = x - self.x0
        r = diff.norm(dim=-1, keepdim=True)
        h = 1. / (alpha + r)
        y = x + beta * h * diff
        
        h_prime = - (h ** 2)
        log_det_jac = ((self.dim - 1) * torch.log1p(beta * h) + torch.log1p(beta * h + beta * h_prime * r)).sum(-1)
        ##########################################################        
        return y, log_det_jac
    
    def inverse(self, y):
        """Compute the inverse transformation given an input y.

        Args:
            y: input sample. shape [batch_size, dim]

        Returns:
            x: sample after inverse tranformation. shape [batch_size, dim]
            inv_log_det_jac: log determinant of the jacobian of the inverse tranformation, shape [batch_size]
        """
        raise ValueError("The inverse tranformation is not known in closed form.")

# %% [markdown]
# ### Stacking tranformations

# %% [markdown]
# To define a more expressive NF model, we need to stack multiple transformations. It's important that every stacked transformation can be computed in the `forward` direction if we want to perform sampling (slide 31). Similarly, we need to be able to compute the `inverse` direction for each transformation if we want to learn the model via MLE (slide 27).

# %% [markdown]
# #### Task 4: stacking tranformations - log_prob (20 pt)
# Implement the method `log_prob` in class `StackedFlows`. This method should compute tthe log density for each sample.

# %% [markdown]
# #### Task 5: stacking tranformations - rsample (20 pt)
# Implement the method `rsample` in class `StackedFlows`. This method should draw a sample from the base distribution, pass it through all the transformations and compute its log density.

# %%
class StackedFlows(nn.Module):
    def __init__(self, transforms, dim=2, base_dist='Normal'):
        """Stack a list of tranformations with a given based distribtuion.

        Args:
            tranforms: list fo stacked tranformations. list of Flows
            dim: dimension of input/output data. int
            base_dist: name of the base distribution. options: ['Normal']
        """
        super().__init__()
        
        if isinstance(transforms, nf.Flow):
            self.transforms = nn.ModuleList([transforms, ])
        elif isinstance(transforms, list):
            if not all(isinstance(t, nf.Flow) for t in transforms):
                raise ValueError("transforms must be a Flow or a list of Flows")
            self.transforms = nn.ModuleList(transforms)
        else:
            raise ValueError(f"transforms must a Flow or a list, but was {type(transforms)}")
            
        self.dim = dim
        if base_dist == "Normal":
            self.base_dist = MultivariateNormal(torch.zeros(self.dim).to(device), torch.eye(self.dim).to(device))
        else:
            raise NotImplementedError

    def log_prob(self, x):
        """Compute log probability of a batch of data (slide 27).

        Args:
            x: input sample. shape [batch_size, dim]

        Returns:
            log_prob: Log probability of the data, shape [batch_size]
        """
        
        ##########################################################
        # YOUR CODE HERE
        inv_log_det = 0.0
        for transform in reversed(self.transforms):
            z, inv_log_det_jacobian = transform.inverse(x)
            inv_log_det += inv_log_det_jacobian
            x = z
        log_base = self.base_dist.log_prob(x)
        log_prob = (inv_log_det + log_base)
        ##########################################################
        
        return log_prob

    def rsample(self, batch_size):
        """Sample from the transformed distribution (slide 31).

        Returns:
            x: sample after forward tranformation, shape [batch_size, dim]
            log_prob: Log probability of x, shape [batch_size]
        """
        ##########################################################
        # YOUR CODE HERE
        x = self.base_dist.rsample([batch_size])
        log_base = self.base_dist.log_prob(x)
        log_det = 0.0
        for transform in self.transforms:
            x, log_det_jacobian = transform.forward(x)
            log_det += log_det_jacobian
        log_prob = - log_det + log_base
        ##########################################################
        
        return x, log_prob

# %% [markdown]
# # 2. Maximum-likelihood training

# %% [markdown]
# We train normalizing flows by maximizing the log-likelihood (Slide 28) of the observed data points $\boldsymbol{x}^{(i)}$ w.r.t. the flow parameters $\varphi$ i.e.:
#
# $$\max_\varphi \frac{1}{|\mathcal{D}|} \sum_{\boldsymbol{x}^{(i)} \in \mathcal{D}} \log p(\boldsymbol{x}^{(i)})$$

# %% [markdown]
# #### Task 6: training - maximum likelihood (15 pt)
# Complete the functions train such that it trains the model with maximum likelihood.
#
# The variable loss should be a scalar equal to the the mean loss for the data in the current batch. Note that here we expect to minimize the negaitve log-likelihood instead of maximizing the log-likelihood.

# %%
def train(model, dataset, batch_size=100, max_epochs=1000, frequency=250):
    """Train a normalizing flow model with maximum likelihood.

    Args:
        model: normalizing flow model. Flow or StackedFlows
        dataset: dataset containing data to fit. Dataset
        batch_size: number of samples per batch. int
        max_epochs: number of training epochs. int
        frequency: frequency for plotting density visualization. int
        
    Return:
        model: trained model. Flow or StackedFlows
        losses: loss evolution during training. list of floats
    """
    # Load dataset
    train_loader = torch.utils.data.DataLoader(dataset, batch_size=batch_size)
    
    # Train model
    losses = []
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-3, weight_decay=1e-6)
    for epoch in range(max_epochs + 1):
        total_loss = 0
        for batch_index, (X_train) in enumerate(train_loader):
            ##########################################################
            # YOUR CODE HERE
            log_probs = model.log_prob(X_train.to(device))
            loss = -log_probs.mean(0)
            ##########################################################
            
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            total_loss += loss      
        total_loss /= len(train_loader)
        losses.append(total_loss)
        
        if epoch % frequency == 0:
            print(f"Epoch {epoch} -> loss: {total_loss.item():.2f}")
            nf.plot_density(model, train_loader, device=device)
    
    return model, losses

# %% [markdown]
# # 3. Results

# %% [markdown]
# We will now fit our models on the following toy datasets:
# - A single Gaussian with non-zero mean
# - Three gaussians
# - Two moons
#
# For each dataset, we train an affine and a radial transformation with a Gaussian base distribution. The affine tranformation should only be able to scale and shift the base distribution. The radial tranformation is capable of more complex transformations.
#
# Plots show:
# - Evolution of density estimation during training.
# - The loss curve during training.
# - The density learned by the model after training.
# - Samples from the model after training (if possible).
#
# If everything is implement correctly, you should see significant changes in the loss value after the first 100 epochs for all datasets.

# %% [markdown]
# ## Dataset 1: shifted Gaussian
# The first dataset composed of one Gaussian with a non zero mean. All flows should manage to fit this density.

# %%
dataset_1 = nf.CircleGaussiansDataset(n_gaussians=1, n_samples=500)
plt.scatter(dataset_1.X[:,0], dataset_1.X[:,1], alpha=.05, marker='x', c='orange')
plt.xlim(-5, 5)
plt.ylim(-5, 5)
plt.show()

# %% [markdown]
# ### Affine flow

# %%
transforms = [Affine().to(device)]
model = StackedFlows(transforms, base_dist='Normal').to(device)
model, losses = train(model, dataset_1, max_epochs=501)

# Plots
plt.plot(losses)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()
nf.plot_density(model, [], device=device)
nf.plot_samples(model)
# Out:
# Epoch 0 -> loss: 6.34
# Epoch 250 -> loss: 2.46
# Epoch 500 -> loss: 2.04

# %%
losses
# Out:
# [tensor(6.3435, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(6.2849, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(6.2272, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(6.1704, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(6.1146, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(6.0597, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(6.0058, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(5.9528, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(5.9008, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(5.8498, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(5.7997, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(5.7506, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(5.7023, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(5.6550, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(5.6085, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(5.5629, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(5.5181, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(5.4741, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(5.4309, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(5.3884, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(5.3468, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(5.3058, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(5.2656, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(5.2260, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(5.1872, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(5.1490, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(5.1115, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(5.0746, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(5.0383, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(5.0026, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(4.9675, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(4.9330, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(4.8991, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(4.8657, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(4.8329, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(4.8006, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(4.7688, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(4.7375, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(4.7067, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(4.6764, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(4.6466, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(4.6172, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(4.5883, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(4.5598, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(4.5318, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(4.5042, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(4.4770, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(4.4502, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(4.4238, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(4.3978, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(4.3722, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(4.3469, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(4.3221, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(4.2976, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(4.2734, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(4.2496, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(4.2261, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(4.2030, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(4.1802, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(4.1577, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(4.1355, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(4.1136, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(4.0920, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(4.0708, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(4.0498, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(4.0291, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(4.0086, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(3.9885, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(3.9686, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(3.9490, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(3.9296, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(3.9105, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(3.8917, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(3.8731, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(3.8547, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(3.8366, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(3.8187, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(3.8010, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(3.7836, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(3.7664, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(3.7493, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(3.7326, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(3.7160, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(3.6996, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(3.6834, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(3.6674, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(3.6517, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(3.6361, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(3.6207, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(3.6055, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(3.5904, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(3.5756, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(3.5609, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(3.5464, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(3.5321, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(3.5179, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(3.5039, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(3.4901, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(3.4764, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(3.4629, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(3.4496, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(3.4364, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(3.4233, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(3.4104, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(3.3977, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(3.3851, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(3.3726, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(3.3603, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(3.3481, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(3.3361, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(3.3241, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(3.3124, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(3.3007, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(3.2892, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(3.2778, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(3.2665, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(3.2554, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(3.2444, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(3.2335, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(3.2227, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(3.2120, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(3.2015, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(3.1911, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(3.1807, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(3.1705, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(3.1604, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(3.1504, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(3.1405, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(3.1308, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(3.1211, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(3.1115, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(3.1020, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(3.0927, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(3.0834, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(3.0742, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(3.0651, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(3.0561, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(3.0473, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(3.0385, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(3.0298, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(3.0211, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(3.0126, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(3.0042, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.9958, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.9876, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.9794, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.9713, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.9633, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.9554, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.9476, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.9398, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.9321, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.9245, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.9170, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.9096, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.9022, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.8949, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.8877, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.8806, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.8735, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.8665, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.8596, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.8527, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.8460, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.8392, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.8326, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.8260, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.8195, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.8131, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.8067, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.8004, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.7942, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.7880, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.7819, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.7759, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.7699, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.7640, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.7581, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.7523, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.7465, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.7409, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.7352, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.7297, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.7242, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.7187, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.7133, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.7080, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.7027, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.6975, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.6923, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.6872, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.6821, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.6771, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.6722, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.6673, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.6624, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.6576, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.6529, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.6482, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.6435, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.6389, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.6343, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.6298, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.6254, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.6210, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.6166, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.6123, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.6080, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.6038, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.5996, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.5954, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.5914, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.5873, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.5833, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.5793, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.5754, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.5715, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.5677, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.5639, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.5601, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.5564, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.5527, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.5491, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.5455, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.5419, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.5384, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.5349, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.5314, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.5280, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.5246, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.5213, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.5180, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.5147, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.5114, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.5082, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.5051, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.5019, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.4988, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.4957, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.4927, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.4897, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.4867, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.4838, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.4808, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.4779, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.4751, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.4723, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.4695, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.4667, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.4639, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.4612, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.4585, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.4559, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.4533, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.4506, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.4481, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.4455, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.4430, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.4405, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.4380, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.4355, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.4331, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.4307, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.4283, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.4259, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.4236, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.4213, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.4190, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.4167, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.4145, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.4122, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.4100, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.4078, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.4057, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.4035, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.4014, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.3992, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.3971, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.3951, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.3930, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.3910, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.3889, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.3869, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.3849, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.3830, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.3810, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.3791, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.3771, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.3752, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.3733, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.3714, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.3695, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.3677, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.3658, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.3640, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.3622, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.3604, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.3586, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.3568, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.3551, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.3533, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.3516, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.3498, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.3481, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.3464, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.3447, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.3430, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.3413, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.3397, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.3380, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.3363, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.3347, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.3331, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.3314, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.3298, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.3282, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.3266, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.3250, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.3235, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.3219, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.3203, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.3187, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.3172, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.3156, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.3141, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.3126, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.3110, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.3095, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.3080, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.3065, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.3050, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.3035, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.3020, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.3005, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.2990, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.2975, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.2961, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.2946, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.2931, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.2916, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.2902, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.2887, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.2873, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.2858, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.2844, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.2829, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.2815, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.2801, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.2786, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.2772, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.2758, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.2743, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.2729, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.2715, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.2701, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.2686, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.2672, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.2658, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.2644, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.2630, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.2616, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.2602, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.2588, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.2573, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.2559, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.2545, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.2531, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.2517, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.2503, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.2489, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.2475, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.2461, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.2447, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.2433, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.2419, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.2405, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.2391, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.2377, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.2363, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.2349, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.2335, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.2321, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.2306, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.2292, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.2278, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.2264, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.2250, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.2236, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.2222, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.2208, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.2194, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.2179, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.2165, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.2151, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.2137, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.2123, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.2108, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.2094, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.2080, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.2065, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.2051, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.2037, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.2022, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.2008, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.1994, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.1979, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.1965, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.1950, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.1936, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.1921, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.1907, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.1892, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.1877, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.1863, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.1848, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.1833, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.1819, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.1804, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.1789, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.1774, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.1759, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.1744, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.1730, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.1715, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.1700, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.1685, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.1669, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.1654, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.1639, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.1624, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.1609, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.1594, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.1578, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.1563, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.1548, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.1532, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.1517, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.1501, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.1486, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.1470, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.1455, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.1439, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.1423, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.1408, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.1392, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.1376, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.1360, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.1344, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.1328, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.1312, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.1296, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.1280, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.1264, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.1248, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.1231, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.1215, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.1199, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.1182, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.1166, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.1149, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.1133, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.1116, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.1099, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.1083, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.1066, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.1049, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.1032, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.1015, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.0998, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.0981, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.0964, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.0947, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.0930, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.0912, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.0895, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.0878, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.0860, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.0843, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.0825, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.0807, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.0790, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.0772, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.0754, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.0736, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.0718, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.0700, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.0682, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.0664, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.0646, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.0627, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.0609, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.0590, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.0572, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.0553, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.0535, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.0516, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.0497, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.0478, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.0459, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.0440, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.0421, device='cuda:0', grad_fn=<DivBackward0>),
#  tensor(2.0402, device='cuda:0', grad_fn=<DivBackward0>)]

# %% [markdown]
# ### Radial flow (4 layers)

# %%
transforms = [Radial().get_inverse().to(device) for _ in range(4)]
model = StackedFlows(transforms, base_dist='Normal').to(device)
model, losses = train(model, dataset_1, max_epochs=1250)

# Plots
plt.plot(losses, marker='*')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()
nf.plot_density(model, [], device=device)
# Out:
# Epoch 0 -> loss: 9.42
# Epoch 250 -> loss: 3.47
# Epoch 500 -> loss: 2.86
# Epoch 750 -> loss: 2.66
# Epoch 1000 -> loss: 2.53
# Epoch 1250 -> loss: 2.43

# %% [markdown]
# ## Dataset 2: 3 Gaussians
# The second dataset is composed of 3 gaussians with means on a circle.

# %%
dataset_2 = nf.CircleGaussiansDataset(n_gaussians=3, n_samples=400, variance=.4)
plt.scatter(dataset_2.X[:,0], dataset_2.X[:,1], alpha=.05, marker='x', c='orange')
plt.xlim(-5, 5)
plt.ylim(-5, 5)
plt.show()

# %% [markdown]
# ### Affine flow

# %%
transforms = [Affine().to(device)]
model = StackedFlows(transforms, base_dist='Normal').to(device)
model, losses = train(model, dataset_2, max_epochs=500)

# Plots
plt.plot(losses, marker='*')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()
nf.plot_density(model, [], device=device)
nf.plot_samples(model)
# Out:
# Epoch 0 -> loss: 6.45
# Epoch 250 -> loss: 4.37
# Epoch 500 -> loss: 4.37

# %% [markdown]
# Affine flow should fail here.

# %% [markdown]
# ### Radial flow (32 layers)

# %%
transforms = [Radial().get_inverse().to(device) for _ in range(32)]
model = StackedFlows(transforms, base_dist='Normal').to(device)
model, losses = train(model, dataset_2, max_epochs=500, frequency=100)

# Plots
plt.plot(losses, marker='*')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()
nf.plot_density(model, [], device=device)
# Out:
# Epoch 0 -> loss: 12.38
# Epoch 100 -> loss: 3.01
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-0939404d3474> in <module>
#       1 transforms = [Radial().get_inverse().to(device) for _ in range(32)]
#       2 model = StackedFlows(transforms, base_dist='Normal').to(device)
# ----> 3 model, losses = train(model, dataset_2, max_epochs=500, frequency=100)
#       4
#       5 # Plots
#
# <ipython-input-13-88dc8fbd4d14> in train(model, dataset, batch_size, max_epochs, frequency)
#      24             ##########################################################
#      25             # YOUR CODE HERE
# ---> 26             log_probs = model.log_prob(X_train.to(device))
#      27             loss = -log_probs.mean(0)
#      28             ##########################################################
#
# <ipython-input-10-08c9d9eda558> in log_prob(self, x)
#      39         inv_log_det = 0.0
#      40         for transform in reversed(self.transforms):
# ---> 41             z, inv_log_det_jacobian = transform.inverse(x)
#      42             inv_log_det += inv_log_det_jacobian
#      43             x = z
#
# ~/teaching/teaching/mlgs_ss21/project/01/nf_utils.py in inverse(self, y)
#      69             inv_log_det_jac: log determinant of the jacobian of the inverse tranformation, shape [batch_size]
#      70         """
# ---> 71         x, inv_log_det_jac = self.base_flow.forward(y)
#      72         return x, inv_log_det_jac
#      73
#
# <ipython-input-4-4371e1ecefa8> in forward(self, x)
#      39         y = x + beta * h * diff
#      40
# ---> 41         h_prime = - (h ** 2)
#      42         log_det_jac = ((self.dim - 1) * torch.log1p(beta * h) + torch.log1p(beta * h + beta * h_prime * r)).sum(-1)
#      43         ##########################################################
#
# KeyboardInterrupt:

# %% [markdown]
# Using 32 layers of radial flow should lead to a good reasonable fit of the data after 500 epochs. Traning with more layers and for more epochs would improve the density estimation but would take more time. You might have to run the training multiple times to learn the three Gaussians (sometimes only two Gaussians are learned by the flow).

# %% [markdown]
# ## Dataset 3: 2 Moons

# %% [markdown]
# The third dataset is composed of 2 moons. Affine flow should fail again. With more layers, Radial flow should work.

# %%
dataset_3 = nf.MoonsDataset()
plt.scatter(dataset_3.X[:,0], dataset_3.X[:,1], alpha=.05, marker='x', c='orange')
plt.xlim(-2.5, 3)
plt.ylim(-2.5, 3)
plt.show()

# %% [markdown]
# ### Affine flow

# %%
transforms = [Affine().to(device)]
model = StackedFlows(transforms, base_dist='Normal').to(device)
model, losses = train(model, dataset_3, max_epochs=500)

# Plots
plt.plot(losses, marker='*')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()
nf.plot_density(model, [], device=device)
nf.plot_samples(model)
# Out:
# Epoch 0 -> loss: 2.49
# Epoch 250 -> loss: 2.00
# Epoch 500 -> loss: 2.00

# %% [markdown]
# Affine flow should fail here.

# %% [markdown]
# ### Radial flow (32 layers)

# %%
transforms = [Radial().get_inverse().to(device) for _ in range(32)]
model = StackedFlows(transforms, base_dist='Normal').to(device)
model, losses = train(model, dataset_3, max_epochs=500, frequency=100)

# Plots
plt.plot(losses, marker='*')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()
nf.plot_density(model, [], mesh_size=3, device=device)
# Out:
# Epoch 0 -> loss: 2.46
# Epoch 100 -> loss: 1.43
# Epoch 200 -> loss: 1.13
# Epoch 300 -> loss: 1.04
# Epoch 400 -> loss: 1.00
# Epoch 500 -> loss: 0.95

# %% [markdown]
# Using 32 layers of radial flow should lead to a good reasonable fit of the data after 500 epochs. Traning with more layers and for more epochs would improve the density estimation but would take more time.
